# %%
# !python --version
# Out:
# Python 3.7.6

# %%
# !which python
# Out:
# /home/raul/miniconda3/bin/python

# %%
# !pip install keras
# !pip install tensorflow
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/raul/.local/lib/python3.7/site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in /home/raul/.local/lib/python3.7/site-packages (from keras) (1.18.3)
# Requirement already satisfied: pyyaml in /home/raul/.local/lib/python3.7/site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in /home/raul/.local/lib/python3.7/site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /home/raul/.local/lib/python3.7/site-packages (from keras) (1.4.1)
# Requirement already satisfied: six in /home/raul/miniconda3/lib/python3.7/site-packages (from h5py->keras) (1.14.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.3.1-cp37-cp37m-manylinux2010_x86_64.whl (320.4 MB)
#      |████████████████████████████████| 320.4 MB 7.1 kB/s  eta 0:00:01     |███████████████████             | 190.4 MB 8.1 MB/s eta 0:00:17     |██████████████████████████████▏ | 302.3 MB 12.3 MB/s eta 0:00:02
# Collecting tensorboard<3,>=2.3.0
#   Using cached tensorboard-2.3.0-py3-none-any.whl (6.8 MB)
# Collecting absl-py>=0.7.0
#   Using cached absl_py-0.10.0-py3-none-any.whl (127 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.13.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.5 MB/s eta 0:00:01
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in /home/raul/miniconda3/lib/python3.7/site-packages (from tensorflow) (1.14.0)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 15.0 MB/s eta 0:00:01
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: wheel>=0.26 in /home/raul/miniconda3/lib/python3.7/site-packages (from tensorflow) (0.34.2)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /home/raul/.local/lib/python3.7/site-packages (from tensorflow) (2.10.0)
# Collecting astunparse==1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Collecting keras-preprocessing<1.2,>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting google-pasta>=0.1.8
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /home/raul/.local/lib/python3.7/site-packages (from tensorflow) (1.18.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/raul/miniconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.22.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /home/raul/miniconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow) (45.2.0.post20200210)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.2.2-py3-none-any.whl (88 kB)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.22.1-py2.py3-none-any.whl (114 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/raul/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/raul/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/raul/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/raul/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/raul/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.6.0)
# Collecting rsa<5,>=3.1.4; python_version >= "3.5"
#   Using cached rsa-4.6-py3-none-any.whl (47 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.1.1-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: zipp>=0.5 in /home/raul/.local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=651acf6d82092c45b144458e464f996c1f6e57af05b59eb18a5734dc9b659bdb
#   Stored in directory: /home/raul/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=70952 sha256=2d08052a3b02c787fe6686c82319660aa132a54218a67c24dbfc32c342895395
#   Stored in directory: /home/raul/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built termcolor wrapt
# Installing collected packages: grpcio, tensorboard-plugin-wit, protobuf, oauthlib, requests-oauthlib, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, google-auth-oauthlib, absl-py, markdown, werkzeug, tensorboard, termcolor, opt-einsum, gast, tensorflow-estimator, astunparse, wrapt, keras-preprocessing, google-pasta, tensorflow
# Successfully installed absl-py-0.10.0 astunparse-1.6.3 cachetools-4.1.1 gast-0.3.3 google-auth-1.22.1 google-auth-oauthlib-0.4.1 google-pasta-0.2.0 grpcio-1.32.0 keras-preprocessing-1.1.2 markdown-3.2.2 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.13.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.6 tensorboard-2.3.0 tensorboard-plugin-wit-1.7.0 tensorflow-2.3.1 tensorflow-estimator-2.3.0 termcolor-1.1.0 werkzeug-1.0.1 wrapt-1.12.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.4.0.44-cp37-cp37m-manylinux2014_x86_64.whl (49.5 MB)
#      |████████████████████████████████| 49.5 MB 10.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /home/raul/.local/lib/python3.7/site-packages (from opencv-python) (1.18.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.4.0.44

# %%
pip freeze
# Out:
# absl-py==0.10.0
# aiohttp==1.1.6
# apturl==0.5.2
# asn1crypto==0.24.0
# astunparse==1.6.3
# async-timeout==3.0.1
# attrs==19.3.0
# backcall==0.1.0
# beautifulsoup4==4.9.1
# bintrees==2.1.0
# bleach==3.1.5
# Brlapi==0.6.6
# bs4==0.0.1
# cachetools==4.1.1
# certifi==2020.4.5.1
# chardet==3.0.4
# command-not-found==0.3
# cryptography==2.1.4
# cupshelpers==1.0
# cycler==0.10.0
# decorator==4.4.2
# defer==1.0.6
# defusedxml==0.6.0
# distro-info===0.18ubuntu0.18.04.1
# docutils==0.16
# entrypoints==0.3
# gast==0.3.3
# giotto-tda==0.2.1
# google-auth==1.22.1
# google-auth-oauthlib==0.4.1
# google-pasta==0.2.0
# grpcio==1.32.0
# h5py==2.10.0
# httplib2==0.9.2
# idna==2.9
# igraph==0.1.11
# importlib-metadata==1.6.0
# ipykernel==5.2.1
# ipython==7.13.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# jedi==0.15.2
# Jinja2==2.11.2
# joblib==0.14.1
# json5==0.9.4
# jsonschema==3.2.0
# jupyter-client==6.1.3
# jupyter-core==4.6.3
# jupyterlab==2.1.0
# jupyterlab-server==1.1.1
# kdtree==0.16
# Keras==2.4.3
# Keras-Preprocessing==1.1.2
# keyring==10.6.0
# keyrings.alt==3.0
# kiwisolver==1.2.0
# language-selector==0.1
# launchpadlib==1.10.6
# lazr.restfulclient==0.13.5
# lazr.uri==1.0.3
# liac-arff==2.4.0
# lockfile==0.12.2
# louis==3.5.0
# macaroonbakery==1.1.3
# Mako==1.0.7
# Markdown==3.2.2
# MarkupSafe==1.1.1
# matplotlib==3.2.1
# mistune==0.8.4
# multidict==4.7.5
# multitasking==0.0.9
# nbconvert==5.6.1
# nbformat==5.0.6
# netifaces==0.10.4
# notebook==6.0.3
# numpy==1.18.3
# oauth==1.0.1
# oauthlib==3.1.0
# olefile==0.45.1
# opencv-python==4.4.0.44
# openml==0.10.2
# opt-einsum==3.3.0
# packaging==20.3
# pandas==1.0.3
# pandocfilters==1.4.2
# parso==0.7.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==5.1.0
# plotly==4.6.0
# pluggy==0.13.1
# prometheus-client==0.7.1
# prompt-toolkit==3.0.5
# protobuf==3.13.0
# ptyprocess==0.6.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# PyAudio==0.2.11
# pycairo==1.16.2
# pycrypto==2.6.1
# pycups==1.9.73
# Pygments==2.6.1
# pygobject==3.26.1
# pygtrie==2.3.3
# pymacaroons==0.13.0
# PyNaCl==1.1.2
# pyparsing==2.4.7
# pyRFC3339==1.0
# pyrsistent==0.16.0
# python-apt==1.6.5+ubuntu0.3
# python-daemon==2.1.2
# python-dateutil==2.8.1
# python-debian==0.1.32
# python-igraph==0.8.2
# python-jsonrpc-server==0.3.4
# python-language-server==0.31.10
# python-stack==0.1.7.11
# python-stack-cli==0.2.15.5
# pytz==2019.3
# pyxdg==0.25
# PyYAML==3.12
# pyzmq==19.0.0
# rangetree==1.0
# reportlab==3.4.0
# requests==2.23.0
# requests-oauthlib==1.3.0
# requests-unixsocket==0.1.5
# retrying==1.3.3
# rsa==4.6
# scikit-learn==0.22.2.post1
# scipy==1.4.1
# scour==0.36
# seaborn==0.10.0
# SecretStorage==2.3.1
# selenium==3.141.0
# Send2Trash==1.5.0
# simplejson==3.13.2
# six==1.14.0
# soupsieve==2.0.1
# stack-require==0.0.2.1
# stack-scaffold==0.0.2b1
# system-service==0.3
# systemd-python==234
# tensorboard==2.3.0
# tensorboard-plugin-wit==1.7.0
# tensorflow==2.3.1
# tensorflow-estimator==2.3.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# texttable==1.6.2
# tornado==6.0.4
# traitlets==4.3.3
# ubuntu-drivers-common==0.0.0
# ufw==0.36
# ujson==1.35
# unattended-upgrades==0.1
# urllib3==1.25.9
# usb-creator==0.3.3
# wadllib==1.3.2
# wcwidth==0.1.9
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# wrapt==1.12.1
# xkit==0.0.0
# xmltodict==0.12.0
# yarl==1.4.2
# yfinance==0.1.54
# zipp==3.1.0
# zope.interface==4.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
import cv2, numpy as np

# %%
#https://gist.github.com/baraldilorenzo/8d096f48a1be4a2d660d
def VGG_19(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))

    if weights_path:
        model.load_weights(weights_path)

    return model

# %%
    im = cv2.resize(cv2.imread('data/train/1.jpg'), (224, 224)).astype(np.float32)
    print(im[0, 0])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-59095a4c9c6b> in <module>
# ----> 1 im = cv2.resize(cv2.imread('data/train/1.jpg'), (224, 224)).astype(np.float32)
#       2 print(im[0, 0])
#
# error: OpenCV(4.4.0) /tmp/pip-req-build-6amqbhlx/opencv/modules/imgproc/src/resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
